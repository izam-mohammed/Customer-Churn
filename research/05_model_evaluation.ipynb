# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/izam/coding/Customer-Churn'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    test_data_path: Path
    model_path: Path
    target_column: str
    models_dir: str

# %%
from CustomerChurn.constants import *
from CustomerChurn.utils.common import read_yaml, create_directories, save_json

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation
        schema =  self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir=config.root_dir,
            test_data_path=config.test_data_path,
            model_path = config.model_path,
            target_column = schema.name,
            models_dir = config.models_dir,
           
        )

        return model_evaluation_config

# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import classification_report
from CustomerChurn.utils.common import load_bin, save_json, round_batch
from CustomerChurn import logger
import matplotlib.pyplot as plt
import seaborn as sns
import dataframe_image as dfi

# %%
class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config
    

    def _eval_metrics(self,actual, pred, dir):
        acc = accuracy_score(actual, pred)
        precision = precision_score(actual, pred)
        recall = recall_score(actual, pred)
        f1 = f1_score(actual, pred)
        rocauc_score = roc_auc_score(actual, pred)

        acc, precision, recall, f1, rocauc_score = round_batch(acc, precision, recall, f1, rocauc_score)

        metric = {
            "Accuracy" : acc,
            "Precision" : precision,
            "Recall": recall,
            "F1 score": f1,
            "roc auc score": rocauc_score,
        }
        logger.info(f"metrics are - {metric}")

        save_json(path=Path(os.path.join(dir, "metirc.json")), data=metric)

        return metric

    def _classification_report(self, actual, pred, dir):
        rpt = classification_report(actual, pred, output_dict=True)
        rpt_df = pd.DataFrame(rpt).transpose()
        rpt_df.loc["accuracy", "support"] = rpt_df.loc["macro avg", "support"]
        dfi.export(rpt_df, os.path.join(dir, "classification_report.png"))               
    
    
    def _eval_pics(self, actual, pred_proba, dir):
        logger.info(actual.shape)
        fpr, tpr, thresholds = roc_curve(actual, pred_proba)
        roc_auc = auc(fpr, tpr)

        # Plot ROC curve
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
        plt.xlabel('False Positive Rate (FPR)')
        plt.ylabel('True Positive Rate (TPR)')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend(loc='lower right')

        plt.savefig(os.path.join(dir, "roc_curve.png"))
        plt.close()
        logger.info(f"Saved the ROC curve image at {os.path.join(dir, 'roc_curve.png')}")

        # plt the pr curve
        pr, rc, thresholds = precision_recall_curve(actual, pred_proba)
        pr_auc = auc(rc, pr)

        plt.figure(figsize=(8, 6))
        plt.plot(rc, pr, color='magenta', lw=2, label='PR curve (AUC = {:.2f})'.format(pr_auc))
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curve')
        plt.legend(loc='lower left')

        plt.savefig(os.path.join(dir, "pr_curve.png"))
        plt.close()
        logger.info(f"Saved the ROC curve image at {os.path.join(dir, 'pr_curve.png')}")

        #confusion matrix
        y_pred = (pred_proba > 0.5).astype(int)
        cm = confusion_matrix(actual, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16})
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.title('Confusion Matrix')

        plt.savefig(os.path.join(dir, "confusion_matrix.png"))
        plt.close()
        logger.info(f"Saved the cunfusion matrix image at {os.path.join(dir, 'confusion_matrix.png')}")

    def _evealuation_pic(self, metrics, dir):
        df = pd.DataFrame(metrics).transpose()
        ax = df.plot(kind='barh', figsize=(11, 17), color=["#B347CB", "#7147CB", "#475FCB", "#47A1CB", "#47CBB3"])
        ax.set_xlabel('Score')
        ax.set_title('Metrics for Different Algorithms')

        # Annotating each bar with the precision and recall values
        for p in ax.patches:
            ax.annotate(f'{p.get_width():.2f}', (p.get_width()+0.01, p.get_y() + p.get_height() / 2.),
                        ha='center', va='center', xytext=(10, 0), textcoords='offset points')
        plt.legend(loc="upper left")
        plt.savefig(os.path.join(dir, "metrics.png"))
        plt.close()
        logger.info(f"Saved the metrics image at {os.path.join(dir, 'metric.png')}")       


    def evaluate(self):
        df = pd.read_csv(self.config.test_data_path)
        X = df.drop([self.config.target_column], axis=1)
        y = df[self.config.target_column]

        model = load_bin(path=Path(self.config.model_path))

        try:
            pred = model.predict(X)
            pred_proba = model.predict_proba(X)[:, 1]
        except Exception as e:
            logger.info("Can't predict with main model")
            raise e

        logger.info(f"predicted {pred.shape[0]} data points")
    
        self._eval_metrics(y, pred, self.config.root_dir)
        self._eval_pics(y, pred_proba, self.config.root_dir)

        models = os.listdir(self.config.models_dir)
        metrics = {}
        for model in models:
            model_path = os.path.join(self.config.models_dir, model)
            trained_model = load_bin(Path(model_path))

            model_name, _ = os.path.splitext(model)
            new_dir = os.path.join(self.config.root_dir, model_name)

            try:
                pred = trained_model.predict(X)
                pred_proba = trained_model.predict_proba(X)[:, 1]
            except Exception as e:
                logger.info(f"Can't predict with the model {model_name}")
                continue

            logger.info(f"predicted with {model}")
            

            create_directories([new_dir])

            metric = self._eval_metrics(y, pred, new_dir)
            self._eval_pics(y, pred_proba, new_dir)
            self._classification_report(y, pred, new_dir)

            metrics[model_name] = metric
        
        self._evealuation_pic(metrics=metrics, dir=self.config.root_dir)

# %%
try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
    model_evaluation_config.evaluate()
except Exception as e:
    raise e
# Out:
# [2023-12-15 23:34:53,766: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2023-12-15 23:34:53,770: INFO: common: yaml file: params.yaml loaded successfully]
# [2023-12-15 23:34:53,775: INFO: common: yaml file: schema.yaml loaded successfully]
# [2023-12-15 23:34:53,776: INFO: common: created directory at: artifacts]
# [2023-12-15 23:34:53,776: INFO: common: created directory at: artifacts/model_evaluation]
# [2023-12-15 23:34:53,832: INFO: common: binary file loaded from: artifacts/model_trainer/model.joblib]
# [2023-12-15 23:34:53,838: INFO: 1790674860: predicted 1409 data points]
# [2023-12-15 23:34:53,846: INFO: 1790674860: metrics are - {'Accuracy': 0.82, 'Precision': 0.674, 'Recall': 0.523, 'F1 score': 0.589, 'roc auc score': 0.72}]
# [2023-12-15 23:34:53,847: INFO: common: json file saved at: artifacts/model_evaluation/metirc.json]
# [2023-12-15 23:34:53,848: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:54,019: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/roc_curve.png]
# [2023-12-15 23:34:54,106: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/pr_curve.png]
# [2023-12-15 23:34:54,211: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/confusion_matrix.png]
# [2023-12-15 23:34:54,229: INFO: common: binary file loaded from: artifacts/model_trainer/models/SVC.joblib]
# [2023-12-15 23:34:54,376: INFO: 1790674860: Can't predict with the model SVC]
# [2023-12-15 23:34:54,377: INFO: common: binary file loaded from: artifacts/model_trainer/models/LogisticRegression.joblib]
# [2023-12-15 23:34:54,380: INFO: 1790674860: predicted with LogisticRegression.joblib]
# [2023-12-15 23:34:54,380: INFO: common: created directory at: artifacts/model_evaluation/LogisticRegression]
# [2023-12-15 23:34:54,389: INFO: 1790674860: metrics are - {'Accuracy': 0.806, 'Precision': 0.631, 'Recall': 0.511, 'F1 score': 0.565, 'roc auc score': 0.707}]
# [2023-12-15 23:34:54,390: INFO: common: json file saved at: artifacts/model_evaluation/LogisticRegression/metirc.json]
# [2023-12-15 23:34:54,390: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:54,490: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/LogisticRegression/roc_curve.png]
# [2023-12-15 23:34:54,578: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/LogisticRegression/pr_curve.png]
# [2023-12-15 23:34:54,667: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/LogisticRegression/confusion_matrix.png]
# [2023-12-15 23:34:55,046: INFO: common: binary file loaded from: artifacts/model_trainer/models/Decision_Tree.joblib]
# [2023-12-15 23:34:55,048: INFO: 1790674860: predicted with Decision_Tree.joblib]
# [2023-12-15 23:34:55,049: INFO: common: created directory at: artifacts/model_evaluation/Decision_Tree]
# [2023-12-15 23:34:55,056: INFO: 1790674860: metrics are - {'Accuracy': 0.732, 'Precision': 0.462, 'Recall': 0.503, 'F1 score': 0.481, 'roc auc score': 0.655}]
# [2023-12-15 23:34:55,057: INFO: common: json file saved at: artifacts/model_evaluation/Decision_Tree/metirc.json]
# [2023-12-15 23:34:55,057: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:55,141: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/Decision_Tree/roc_curve.png]
# [2023-12-15 23:34:55,218: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/Decision_Tree/pr_curve.png]
# [2023-12-15 23:34:55,307: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/Decision_Tree/confusion_matrix.png]
# [2023-12-15 23:34:55,708: INFO: common: binary file loaded from: artifacts/model_trainer/models/AdaBoost.joblib]
# [2023-12-15 23:34:55,783: INFO: 1790674860: predicted with AdaBoost.joblib]
# [2023-12-15 23:34:55,784: INFO: common: created directory at: artifacts/model_evaluation/AdaBoost]
# [2023-12-15 23:34:55,791: INFO: 1790674860: metrics are - {'Accuracy': 0.815, 'Precision': 0.656, 'Recall': 0.526, 'F1 score': 0.584, 'roc auc score': 0.718}]
# [2023-12-15 23:34:55,791: INFO: common: json file saved at: artifacts/model_evaluation/AdaBoost/metirc.json]
# [2023-12-15 23:34:55,792: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:55,870: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/AdaBoost/roc_curve.png]
# [2023-12-15 23:34:55,947: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/AdaBoost/pr_curve.png]
# [2023-12-15 23:34:56,037: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/AdaBoost/confusion_matrix.png]
# [2023-12-15 23:34:56,435: INFO: common: binary file loaded from: artifacts/model_trainer/models/Random_Forest.joblib]
# [2023-12-15 23:34:56,476: INFO: 1790674860: predicted with Random_Forest.joblib]
# [2023-12-15 23:34:56,476: INFO: common: created directory at: artifacts/model_evaluation/Random_Forest]
# [2023-12-15 23:34:56,483: INFO: 1790674860: metrics are - {'Accuracy': 0.807, 'Precision': 0.645, 'Recall': 0.486, 'F1 score': 0.554, 'roc auc score': 0.699}]
# [2023-12-15 23:34:56,484: INFO: common: json file saved at: artifacts/model_evaluation/Random_Forest/metirc.json]
# [2023-12-15 23:34:56,484: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:56,670: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/Random_Forest/roc_curve.png]
# [2023-12-15 23:34:56,746: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/Random_Forest/pr_curve.png]
# [2023-12-15 23:34:56,835: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/Random_Forest/confusion_matrix.png]
# [2023-12-15 23:34:57,238: INFO: common: binary file loaded from: artifacts/model_trainer/models/GradientBoost.joblib]
# [2023-12-15 23:34:57,246: INFO: 1790674860: predicted with GradientBoost.joblib]
# [2023-12-15 23:34:57,248: INFO: common: created directory at: artifacts/model_evaluation/GradientBoost]
# [2023-12-15 23:34:57,258: INFO: 1790674860: metrics are - {'Accuracy': 0.813, 'Precision': 0.665, 'Recall': 0.491, 'F1 score': 0.565, 'roc auc score': 0.705}]
# [2023-12-15 23:34:57,259: INFO: common: json file saved at: artifacts/model_evaluation/GradientBoost/metirc.json]
# [2023-12-15 23:34:57,259: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:57,346: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/GradientBoost/roc_curve.png]
# [2023-12-15 23:34:57,417: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/GradientBoost/pr_curve.png]
# [2023-12-15 23:34:57,507: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/GradientBoost/confusion_matrix.png]
# [2023-12-15 23:34:57,867: INFO: common: binary file loaded from: artifacts/model_trainer/models/XGBoost.joblib]
# [2023-12-15 23:34:57,872: INFO: 1790674860: predicted with XGBoost.joblib]
# [2023-12-15 23:34:57,873: INFO: common: created directory at: artifacts/model_evaluation/XGBoost]
# [2023-12-15 23:34:57,881: INFO: 1790674860: metrics are - {'Accuracy': 0.82, 'Precision': 0.674, 'Recall': 0.523, 'F1 score': 0.589, 'roc auc score': 0.72}]
# [2023-12-15 23:34:57,882: INFO: common: json file saved at: artifacts/model_evaluation/XGBoost/metirc.json]
# [2023-12-15 23:34:57,882: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:57,961: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/XGBoost/roc_curve.png]
# [2023-12-15 23:34:58,036: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/XGBoost/pr_curve.png]
# [2023-12-15 23:34:58,123: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/XGBoost/confusion_matrix.png]
# [2023-12-15 23:34:58,670: INFO: common: binary file loaded from: artifacts/model_trainer/models/LGBM.joblib]
# [2023-12-15 23:34:58,673: INFO: 1790674860: predicted with LGBM.joblib]
# [2023-12-15 23:34:58,674: INFO: common: created directory at: artifacts/model_evaluation/LGBM]
# [2023-12-15 23:34:58,681: INFO: 1790674860: metrics are - {'Accuracy': 0.818, 'Precision': 0.695, 'Recall': 0.471, 'F1 score': 0.562, 'roc auc score': 0.702}]
# [2023-12-15 23:34:58,682: INFO: common: json file saved at: artifacts/model_evaluation/LGBM/metirc.json]
# [2023-12-15 23:34:58,683: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:58,761: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/LGBM/roc_curve.png]
# /home/izam/miniconda3/envs/customerchurn/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# [2023-12-15 23:34:58,838: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/LGBM/pr_curve.png]
# [2023-12-15 23:34:58,915: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/LGBM/confusion_matrix.png]
# [2023-12-15 23:34:59,291: INFO: common: binary file loaded from: artifacts/model_trainer/models/MultinomialNB.joblib]
# [2023-12-15 23:34:59,294: INFO: 1790674860: predicted with MultinomialNB.joblib]
# [2023-12-15 23:34:59,295: INFO: common: created directory at: artifacts/model_evaluation/MultinomialNB]
# [2023-12-15 23:34:59,302: INFO: 1790674860: metrics are - {'Accuracy': 0.793, 'Precision': 0.608, 'Recall': 0.454, 'F1 score': 0.52, 'roc auc score': 0.679}]
# [2023-12-15 23:34:59,303: INFO: common: json file saved at: artifacts/model_evaluation/MultinomialNB/metirc.json]
# [2023-12-15 23:34:59,303: INFO: 1790674860: (1409,)]
# [2023-12-15 23:34:59,381: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/MultinomialNB/roc_curve.png]
# [2023-12-15 23:34:59,459: INFO: 1790674860: Saved the ROC curve image at artifacts/model_evaluation/MultinomialNB/pr_curve.png]
# [2023-12-15 23:34:59,674: INFO: 1790674860: Saved the cunfusion matrix image at artifacts/model_evaluation/MultinomialNB/confusion_matrix.png]
# [2023-12-15 23:35:00,225: INFO: 1790674860: Saved the metrics image at artifacts/model_evaluation/metric.png]
